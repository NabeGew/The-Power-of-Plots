# %% [markdown]
# ## Observations and Insights

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_table = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="left")
merge_table.head()

# Display the data table for preview
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Display the dataframe for preview
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Checking the number of mice.
mouse_metadata["Mouse ID"].value_counts() #g989 has 2 entries, maximum of 1
study_results["Mouse ID"].value_counts() #g989 has 13 entries, maximum of 10
# Out:
# g989    13
# x822    10
# c758    10
# x581    10
# m601    10
#         ..
# u153     1
# n482     1
# o848     1
# b447     1
# t573     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
#Locate the g989 rows in the drug data
g989Drug = mouse_metadata.loc[mouse_metadata["Mouse ID"] == "g989", :]
g989Drug #each g989 has a diffrent drug: stelasyn, propriva
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 107     g989     Propriva  Female          21          26

# %%
#Find the g989 rows in the clinical data
g989Trial = study_results.loc[study_results["Mouse ID"] == "g989", :]
g989Trial

#Remove g989 data from both data sets
clean_mouse_metadata = mouse_metadata.loc[mouse_metadata["Mouse ID"] != "g989", :]
clean_study_results = study_results.loc[study_results["Mouse ID"] != "g989", :]

#Merge data tables
drugData = pd.merge(clean_mouse_metadata, clean_study_results, on="Mouse ID", how="outer")
drugData.head(20)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# ...

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mean = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
stdv = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()
summary_df = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": stdv, 
                          "SEM": sem})

# display Summary statistics table
summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
grouped_df = pd.DataFrame(merge_table.groupby(["Drug Regimen"]).count()).reset_index()

# Filter the DataFrame down only to those columns to chart
regimen_datapoints = grouped_df[["Drug Regimen","Mouse ID"]]
regimen_datapoints = regimen_datapoints.rename(columns={"Mouse ID": "Count"})
# Set the index to be "Drug Regimen" so they will be used as labels
regimen_datapoints = regimen_datapoints.set_index("Drug Regimen")

# Use DataFrame.plot() in order to create a bar chart of the data
regimen_datapoints.plot(kind="bar", color="maroon", figsize=(10,3))

# Set a title for the chart
plt.title("Total Count from data point for each Drug Regimen")

plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
drug_regimens = summary_df.index.tolist()
drug_regimens
# Convert regimen count into a list
regimen_count = (merge_table.groupby(["Drug Regimen"])["Age_months"].count()).tolist()
regimen_count
# Out:
# [230, 178, 178, 188, 186, 181, 161, 228, 181, 182]

# %%
# Define x-axis
x_axis = drug_regimens
x_axis = np.arange(len(regimen_count))
# Create a bar chart based upon the above data
plt.figure(figsize=(10,4))
plt.bar(x_axis, regimen_count, color='b', alpha=0.5, align="center")
# Set a Title and labels
plt.title("Count of data points for each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_df = pd.DataFrame(merge_table.groupby(["Sex"]).count()).reset_index()
gender_df.head()

# Filter Dataframe to those columns, charts
gender_df = gender_df[["Sex","Mouse ID"]]
gender_df = gender_df.rename(columns={"Mouse ID": "Count"})
gender_df.head()
# Out:
#       Sex  Count
# 0  Female    935
# 1    Male    958

# %%
# Plot chart
plt.figure(figsize=(10,6))
ax1 = plt.subplot(121, aspect='equal')
gender_df.plot(kind='pie', y = "Count", ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=True, labels=gender_df['Sex'], legend = False, fontsize=16, colors =["Cyan","Red"])

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_count = (merge_table.groupby(["Sex"])["Age_months"].count()).tolist()
gender_count

# Label the sections of our pie chart
labels = ["Females", "Males"]

# The colors of each section of the pie chart
colors = ["Cyan", "Red"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0)

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(gender_count, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc8bbbcf310>,
# ...
#  [Text(-0.7887477729166416, -0.904365496201087, 'Females'),
#   Text(0.723018791840255, 0.8290017048509963, 'Males')],
#  [Text(-0.4601028675347076, -0.527546539450634, '49.4%'),
#   Text(0.39437388645832083, 0.4521827481005434, '50.6%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. Calculate the IQR and quantitatively determine if there are any potential outliers.
merge_table.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Sort data by Drug Regime, Mouse ID and Timepoint
sorted_df = merge_table.sort_values(["Drug Regimen", "Mouse ID", "Timepoint"], ascending=True)

# Select final volume of each mouse 
max_df = sorted_df.loc[sorted_df["Timepoint"] == 45]
max_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    309     b128    Capomulin  Female           9          22         45
# 1    299     b742    Capomulin    Male           7          21         45
# 2    244     g288    Capomulin    Male           3          19         45
# 3    360     g316    Capomulin  Female          22          22         45
# 4    440     i557    Capomulin  Female           1          24         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           37.074024                 1
# 3           40.159220                 2
# 4           47.685963                 1

# %%
# Select data for Capomulin regimen and reset index
cap_data_df = max_df[max_df['Drug Regimen'].isin(['Capomulin'])]
cap_data_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    309     b128    Capomulin  Female           9          22         45
# 1    299     b742    Capomulin    Male           7          21         45
# 2    244     g288    Capomulin    Male           3          19         45
# 3    360     g316    Capomulin  Female          22          22         45
# 4    440     i557    Capomulin  Female           1          24         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           37.074024                 1
# 3           40.159220                 2
# 4           47.685963                 1

# %%
# Convert "Tumor Volume" Capomulin regimen into dataframe
cap_list = cap_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
cap_list = cap_list["Tumor Volume (mm3)"]
cap_list
# Out:
# 0     23.343598
# 1     28.430964
# 2     28.484033
# 3     31.023923
# 4     31.896238
# 5     32.377357
# 6     33.329098
# 7     34.455298
# 8     36.041047
# 9     37.074024
# 10    37.311846
# 11    38.125164
# 12    38.846876
# 13    38.939633
# 14    38.982878
# 15    40.159220
# 16    40.658124
# 17    40.728578
# 18    41.483008
# 19    41.581521
# 20    47.685963
# Name: Tumor Volume (mm3), dtype: float64

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = cap_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 32.37735684
# The upper quartile of temperatures is: 40.1592203
# The interquartile range of temperatures is: 7.781863460000004
# The the median of temperatures is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Example outlier plot of final total volume
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume for Capomulin Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(cap_list)
plt.show()

# %%
# Select data for Ramicane regimen and reset index
ram_data_df = max_df[max_df['Drug Regimen'].isin(['Ramicane'])]
ram_data_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    327     a411     Ramicane    Male           3          22         45
# 1    430     a444     Ramicane  Female          10          25         45
# 2    214     a520     Ramicane    Male          13          21         45
# 3    174     a644     Ramicane  Female           7          17         45
# 4    154     c758     Ramicane    Male           9          17         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.407618                 1
# 1           43.047543                 0
# 2           38.810366                 1
# 3           32.978522                 1
# 4           33.397653                 1

# %%
# Convert "Tumor Volume" Ramicane regimen into dataframe Ramicane 
ram_list = ram_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
ram_list = ram_list["Tumor Volume (mm3)"]
ram_list
# Out:
# 0     22.050126
# 1     29.128472
# 2     30.276232
# 3     30.564625
# 4     30.638696
# 5     31.095335
# 6     31.560470
# 7     32.978522
# 8     33.397653
# 9     33.562402
# 10    36.134852
# 11    36.374510
# 12    37.225650
# 13    37.311236
# 14    38.407618
# 15    38.810366
# 16    40.659006
# 17    40.667713
# 18    43.047543
# 19    45.220869
# Name: Tumor Volume (mm3), dtype: float64

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = ram_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 30.981175224999998
# The upper quartile of temperatures is: 38.508305307499995
# The interquartile range of temperatures is: 7.527130082499998
# The the median of temperatures is: 34.848627300000004
# Values below 19.690480101250003 could be outliers.
# Values above 49.79900043124999 could be outliers.

# %%
# outlier plot of final total volumes
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume for Ramicane Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(cap_list)
plt.show()

# %%
# Select data for Infubinol regimen and reset index
inf_data_df = max_df[max_df['Drug Regimen'].isin(['Infubinol'])]
inf_data_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    463     a203    Infubinol  Female          20          23         45
# 1    473     a251    Infubinol  Female          21          25         45
# 2    540     a685    Infubinol    Male           8          30         45
# 3    637     c139    Infubinol    Male          11          28         45
# 4    800     e476    Infubinol    Male          23          26         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           66.083066                 3
# 3           72.226731                 2
# 4           62.435404                 1

# %%
# Convert "Tumor Volume" Infubinol regimen into dataframe Ramicane 

inf_list = inf_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
inf_list = inf_list["Tumor Volume (mm3)"]
inf_list
# Out:
# 0    60.918767
# 1    62.435404
# 2    62.754451
# 3    65.525743
# 4    66.083066
# 5    66.196912
# 6    67.685569
# 7    67.973419
# 8    72.226731
# Name: Tumor Volume (mm3), dtype: float64

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = inf_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 62.75445141
# The upper quartile of temperatures is: 67.68556862
# The interquartile range of temperatures is: 4.9311172099999965
# The the median of temperatures is: 66.08306589
# Values below 55.35777559500001 could be outliers.
# Values above 75.08224443499999 could be outliers.

# %%
# outlier plot of final total volumes
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume for Infubinol Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(inf_list)
plt.show()

# %%
# Select data for Ceftamin regimen and reset index
cef_data_df = max_df[max_df['Drug Regimen'].isin(['Ceftamin'])]
cef_data_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    493     a275     Ceftamin  Female          20          28         45
# 1    993     j296     Ceftamin  Female          24          30         45
# 2   1033     k210     Ceftamin    Male          15          28         45
# 3   1112     l471     Ceftamin  Female           7          28         45
# 4   1132     l661     Ceftamin    Male          18          26         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           62.999356                 3
# 1           61.849023                 3
# 2           68.923185                 3
# 3           67.748662                 1
# 4           59.851956                 3

# %%
# Convert "Tumor Volume" Ceftamin regimen into dataframe
cef_list = cef_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
cef_list = cef_list["Tumor Volume (mm3)"]
cef_list
# Out:
# 0     59.741901
# 1     59.851956
# 2     61.386660
# 3     61.433892
# 4     61.849023
# 5     62.999356
# 6     64.299830
# 7     64.634949
# 8     64.729837
# 9     67.527482
# 10    67.748662
# 11    68.594745
# 12    68.923185
# Name: Tumor Volume (mm3), dtype: float64

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = cef_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 61.43389223
# The upper quartile of temperatures is: 67.52748237
# The interquartile range of temperatures is: 6.093590140000003
# The the median of temperatures is: 64.29983003
# Values below 52.29350701999999 could be outliers.
# Values above 76.66786758 could be outliers.

# %%
# outlier plot of final total volumes
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume for Ceftamin Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(cef_list)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
capomulin_df = merge_table.loc[merge_table["Drug Regimen"] == "Capomulin"]
capomulin_df = capomulin_df.reset_index()
capomulin_df.head()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# 2           37.614948                 0
# 3           38.177232                 0
# 4           36.866876                 0

# %%
# Data from single mouse from test
cap_single_df = capomulin_df.loc[capomulin_df["Mouse ID"] == "s185"]
cap_single_df
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
# 5     15     s185    Capomulin  Female           3          17         25
# 6     16     s185    Capomulin  Female           3          17         30
# 7     17     s185    Capomulin  Female           3          17         35
# 8     18     s185    Capomulin  Female           3          17         40
# 9     19     s185    Capomulin  Female           3          17         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# ...

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
# 2 columns
cap_single_df = cap_single_df.loc[:, ["Timepoint", "Tumor Volume (mm3)"]]
#capomulin_df.index
#Reset the index
cap_single_df = cap_single_df.reset_index(drop=True)
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
cap_single_df.set_index('Timepoint').plot(figsize=(10, 8), linewidth=2.5, color='cyan')

# %% [markdown]
# ## Correlation and Regression

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin treatment regimen.
capomulin_df.head()

# Selecting 3 columns
reduced_df = capomulin_df.loc[:, ["Mouse ID", "Weight (g)", "Tumor Volume (mm3)"]]
reduced_df.head()
# Out:
#   Mouse ID  Weight (g)  Tumor Volume (mm3)
# 0     s185          17           45.000000
# 1     s185          17           43.878496
# 2     s185          17           37.614948
# 3     s185          17           38.177232
# 4     s185          17           36.866876

# %%
# Calculate average for Capomulin regimen
average_cap = pd.DataFrame(reduced_df.groupby(["Mouse ID", "Weight (g)"])["Tumor Volume (mm3)"].mean()).reset_index()
average_cap.head()
# Out:
#   Mouse ID  Weight (g)  Tumor Volume (mm3)
# 0     b128          22           41.963636
# 1     b742          21           40.083699
# 2     f966          17           36.505973
# 3     g288          19           41.990097
# 4     g316          22           44.613344

# %%
# Rename Tumor Volume column
average_cap = average_cap.rename(columns={"Tumor Volume (mm3)": "Average Volume"})
average_cap.head()
# Out:
#           Weight (g)  Average Volume
# Mouse ID
# b128              22       41.963636
# b742              21       40.083699
# f966              17       36.505973
# g288              19       41.990097
# g316              22       44.613344

# %%
# Create scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
average_cap.plot(kind="scatter", x="Weight (g)", y="Average Volume", grid=True, figsize=(6,6),
              title="Weight Vs. Overall Average Tumor Volume", color="red")
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Calculate the correlation coefficient between mouse weight and average tumor volume for the Capomulin regimen
mouse_weight = average_cap.iloc[:,0]
avg_tumor_volume = average_cap.iloc[:,1]
correlation = st.pearsonr(mouse_weight,avg_tumor_volume)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.84

# %%
# Add the linear regression equation and line to plot
x_values = average_cap['Weight (g)']
y_values = average_cap['Average Volume']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Mouse Weight')
plt.ylabel('Overall Tumor Volume')
plt.show()
